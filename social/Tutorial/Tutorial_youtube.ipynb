# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <h1>Tutorial API di YouTube</h1>
#     <img src="immagini/logo_sfondo.png" width="100" height="60">
# </div>
#
# **Nome**: *Matteo*
#
# **Cognome**: *Vullo*
#
# **Matricola**: *1000034661*
#
# **Corso**: Social Media Data Analisys
#
# **Docente**: Francesco Ragusa
#
# **Anno Accademico**: *2023/2024*
#
# ## Indice
# <ol>
#     <li><a href="#introduzione">Introduzione</a></li>
#     <li><a href="#profilo-e-applicazione">Profilo e applicazione</a></li>
#     <li><a href="#accesso-alle-api">Accesso alle API</a></li>
#     <li><a href="#estrazioni-dati-e-analisi">Estrazione dati e analisi</a></li>
#     <li><a href="#conclusione">Conclusione</a></li>
# </ol>

# %% [markdown]
# <section id="introduzione">
#     <h2>1. Introduzione</h2>
# </section>

# %% [markdown]
# <p>
# YouTube è una piattaforma di condivisione video online creata nel 2005 da Chad Hurley, Steve Chen e Jawed Karim, e successivamente acquisita da Google. Questa piattaforma permette agli utenti di caricare, visualizzare e condividere video di ogni genere, dai video casalinghi agli spettacoli televisivi, passando per tutorial, recensioni, musica e molto altro. YouTube è diventato uno dei siti web più popolari al mondo, offrendo una vasta gamma di contenuti multimediali provenienti da creatori di tutto il mondo. Gli utenti possono commentare i video, mettere "Mi piace" o "Non mi piace" e iscriversi ai canali dei creatori preferiti. La piattaforma è diventata un importante mezzo di espressione, intrattenimento e apprendimento per milioni di persone in tutto il mondo.
# </p>
# <p>
#     <a href="https://developers.google.com/youtube/v3/docs" target="_blank">Documentazione YouTube API</a><br>
# </p>
# <p>
#     <img src="Immagini/Introduzione.png"><br>
# </p>

# %% [markdown]
# <section id="profilo-e-applicazione">
#     <h2>2. Profilo e applicazione</h2>
# </section>

# %% [markdown]
# ### Cos' è Google?
# <p>
# Google è una delle più grandi e influenti aziende di tecnologia al mondo. Fondata nel 1998 da Larry Page e Sergey Brin, è nota soprattutto per il suo motore di ricerca omonimo, che è diventato uno dei più utilizzati al mondo. Google offre una vasta gamma di servizi e prodotti, tra cui il sistema operativo Android, il browser Chrome, servizi di cloud computing come Google Cloud, piattaforme per la pubblicità online, servizi di mappe e navigazione come Google Maps, e molto altro.
# </p>

# %% [markdown]
# ### Creazione di un profilo utente
# <p>Prima di tutto è necessario creare o accedere a un proprio profilo google e per farlo basta dirigersi al seguente link: <a target="blank_" href="https://accounts.google.com">https://accounts.google.com</a></p>
# <p>
#     Se gia si possiede un account google è necessario effettuare l'accesso con le proprie credenziali
# </p>
# <p>
#     Inserire l'e-mail e fai clic su "Avanti"
# </p>
# <img src="Immagini/Registrazione.png">
# <p>
#     Inserire la password e fai clic su "Avanti"
# </p>
# <img src="Immagini/password_a.png">
# <p>
#     Nel caso in cui non si possiede un account google è necessario crearlo seguento dei semplici passaggi
# </p>
# <p>
#     Fai clic su "crea un account"
# </p>
# <img src="Immagini/Registrazione.png">
# <p>
#     Inserire nome e cognome e fai clic su "Avanti"
# </p>
# <img src="Immagini/nome.png">
# <p>
#     Inserire giorno, mese, anno di nascita e genere e fai clic su "Avanti"
# </p>
# <img src="Immagini/nascita.png">
# <p>
#     Crea un indirizzo e-mail e fai clic su "Avanti"
# </p>
# <img src="Immagini/email.png">
# <p>
#     Crea una password sicura e fai clic su "Avanti"
# </p>
# <img src="Immagini/password.png">
# <p>
#     Inserire un numero di telefono(Opzionale) e fai clic su "Avanti"
# </p>
# <img src="Immagini/numero.png">
# <p>
#     Inserire un email di recupero(Opzionale) e fai clic su "Avanti"
# </p>
# <img src="Immagini/recupero.png">
# <p>
#     Scegli tra le due impostazioni
# </p>
# <img src="Immagini/impostazioni.png">
# <p>
#     Scendi fino alla fine e fai clic su "Conferma"
# </p>
# <img src="Immagini/impostazioni2.png">
# <p>
#     Scendi fino alla fine e fai clic su "Accetta tutto"
# </p>
# <img src="Immagini/privacy1.png">
# <p>
#     Controlla le informazioni inserite e fai clic su "Avanti"
# </p>
# <img src="Immagini/controlla.png">
# <p>
#     Dopo questi semplici passaggi l'account è stato creato correttamente
# </p>

# %% [markdown]
# <section id="accesso-alle-api">
#     <h2>3. Accesso all'API</h2>
# </section>

# %% [markdown]
# ### Cos'è un API?
# <p>
# Un API (Interfaccia di Programmazione delle Applicazioni) è un insieme di regole e protocolli che permette a diverse applicazioni software di comunicare tra loro. Serve come intermediario che consente a un'applicazione di richiedere e scambiare dati con un'altra, spesso in modo standardizzato e ben definito, semplificando l'integrazione e l'interazione tra sistemi diversi.
# </p>

# %% [markdown]
# ### API di YouTube
# <p>
#     Dopo aver creato l'account o aver effettuato l'accesso è necessario dirigersi al seguente link:
#     <a href="https://console.cloud.google.com/" target="_blank">Console google</a><br>
# </p>

# %% [markdown]
# ### Cos'è Google Cloud Console?
# <p>
# Google Cloud Console è un'interfaccia web fornita da Google Cloud Platform (GCP) che consente agli utenti di gestire e monitorare le risorse e i servizi cloud offerti da Google. Attraverso la Console Google Cloud, gli utenti possono creare e configurare macchine virtuali, archiviare dati, implementare applicazioni, gestire le risorse di rete e molto altro. La Console fornisce anche strumenti per il monitoraggio delle prestazioni, la gestione delle autorizzazioni, la fatturazione e la sicurezza delle risorse cloud. È uno strumento essenziale per gli sviluppatori, gli amministratori di sistema e le aziende che utilizzano i servizi cloud di Google per le loro operazioni e applicazioni.
# </p>

# %% [markdown]
# ### Accetazioni termini di servizio
# <p>
#     Il primo passo da effettuare consiste nell' accettazione dei termini e le condizoni di servzio per l'utilizzo dell'api
# </p>
# <p>
#     <img src="Immagini/Accettare.png"><br>
# </p>

# %% [markdown]
# ### Creazione progetto
# <p>
#     Una volta effettuato l'accesso, fai clic su "Seleziona un progetto" nella parte superiore dello schermo
# </p>
# <img src="Immagini/home.png"><br>
# <p>
#     e quindi fai clic su  "Nuovo progetto"
# </p>
# <img src="Immagini/p1.png"><br>
# <p>
#     Assegna un nome al tuo progetto, seleziona il tuo paese/regione e fai clic su "Crea"
# </p>
# <img src="Immagini/p2.png"><br>

# %% [markdown]
# <p>
# Nel pannello di controllo del tuo progetto su GCP, fai clic su "API e servizi" nel menu di sinistra
# </p>
# <img src="Immagini/biblioteca.png"><br>
# <p>
# Fai clic su "Biblioteca" e cerca "YouTube Data API v3".
# </p>
# <img src="Immagini/cerca.png"><br>
# <p>
# Fai clic sulla API trovata e successivamente fai clic su "Abilita"
# </p>
# <img src="Immagini/abilita.png"><br>

# %% [markdown]
# ### Cos'è una chiave API?
# <p>
# Le chiavi API sono sequenze di caratteri uniche che vengono assegnate a un'applicazione o a un utente per confermare l'autenticazione delle richieste API. Di solito, queste chiavi vengono trasmesse come parte delle richieste API e permettono ai server di riconoscere e approvare l'accesso. Le chiavi API servono spesso a gestire l'autorizzazione e a monitorare le richieste API.
# </p>

# %% [markdown]
# ### Ottieni le Chiavi API:
#
# <p>
# Sempre nel pannello di controllo del progetto, fai clic su "Credenziali" nel menu di sinistra.
# </p>
# <img src="Immagini/credenziali.png"><br>
# <p>
# Fai clic su "Crea credenziali" e seleziona "Chiave API"
#
# </p>
# <img src="Immagini/crea.png"><br>
# <p>
# Sarà creata una nuova chiave API.
# </p>
# <img src="Immagini/chiudi.png"><br>
# <p>
# Configura le restrizioni e le autorizzazioni per la tua chiave API, come limiti di utilizzo (se necessario) e restrizioni IP (ad esempio, per limitare le richieste solo al tuo server).
# </p>
# <p>
# La chiave API appena creata può essere utilizzata per eseguire richieste alle API pubbliche di YouTube Data.
# </p>

# %% [markdown]
# ### Cos'è Oauth?
# <p>
# OAuth è un protocollo che permette a un'applicazione di terze parti di accedere a determinate informazioni o risorse in un servizio online a nome di un utente senza richiedere le credenziali di accesso dirette dell'utente. Quindi, quando un'applicazione di terze parti desidera accedere a dati su un sito web attendibile (come Gmail), OAuth consente di farlo senza dover condividere direttamente il nome utente e la password dell'utente con l'applicazione di terze parti.
# </p>

# %% [markdown]
# ### Schermata di consenso Oauth 2.0
# <p>
# Nel pannello "Credenziali" del tuo progetto, fai clic su "Crea credenziali" e seleziona "ID client OAuth"
# </p>
#
# <img src="Immagini/oauth.png"><br>
# <p>
# Cliccare su "configura schermata di consenso"
# </p>
#
# <img src="Immagini/configura.png"><br>
# <p>
# Scegliere tra "Interno" o "Esterno", per i nostri scopi utilizzaremo "Esterno"
# </p>
# <img src="Immagini/s0.png"><br>
# <p>Schermata di consenso</p>
# <p>Inserire un nome per l'applicazione e l'email per assistenza utenti </p>
# <img src="Immagini/schermata.png"><br>
# <p>Inserire i domini</p>
# <img src="Immagini/s.png"><br>
# <p>Inserire le informazioni di contatto dello sviluppatore</p>
# <img src="Immagini/s1.png"><br>
# <p>
# Ambiti
# </p>
# <p>
# Configura le restrizioni per il tuo cliente OAuth, come gli URI di reindirizzamento consentiti.
# </p>
# <img src="Immagini/a.png"><br>
# <img src="Immagini/ambiti2.png"><br>
# <p>
# Utenti
# </p>
# <p>
# Inserire degli utenti utilizzado il tasto "add users"
# </p>
#
# <img src="Immagini/Utenti.png"><br>
# <p>
# Riepilogo
# </p>
#
# <img src="Immagini/riepilogo.png"><br>
# <img src="Immagini/riepilogo2.png"><br>

# %% [markdown]
# ### Creazione di un Cliente OAuth 2.0
# <p>
# Nel pannello "Credenziali" del tuo progetto, fai clic su "Crea credenziali" e seleziona "ID client OAuth". Sarà necessario impostare un nome per il client.
# <p>
# <img src="Immagini/oauth.png"><br>
#
# <p>
# Seleziona il tipo di applicazione appropriato, ad esempio "Applicazione Web" o "Applicazione server" a seconda di dove desideri utilizzare le autorizzazioni.
# </p>
# <img src="Immagini/id.png"><br>
#
# <p>
# Configura le restrizioni per il tuo cliente OAuth, come gli URI di reindirizzamento consentiti.
# </p>
# <p> Dopo fai clic su "scarica json" <div>(servira successivamente per l'estrazione dei dati)</div> </p>
# <img src="Immagini/id_c.png"><br>
#
# <p>
# Fai clic su "scarica json"
# </p>
# <p>
# Dopo aver creato il cliente OAuth, otterrai un ID client e un segreto client. Questi dati saranno utilizzati per gestire l'autenticazione OAuth nel tuo codice.
# <p>
# <p>
# Per poter utilizzare l'autenticazione Oauth è necessario aggiungere un "user" che potrà utilizzare l'api. In questo caso inseriemo l'email dell'account con la quale ci siamo registrati
# </p>
# <img src="Immagini/add_user.png"><br>

# %% [markdown]
# <section id="estrazione-dati-e-analisi">
#     <h2>4. Estrazione dati e analisi</h2>
# </section>

# %% [markdown]
# <p>
# Per effettuare l'estrazione di dati e l'analisi utilizzeremo il linguaggio di programmazione Python
# </p>

# %% [markdown]
# ### Cos'è Python?
# <p>
# Python è un linguaggio di programmazione ad alto livello, interpretato e general-purpose. È noto per la sua sintassi chiara e leggibile, che lo rende facile da imparare e utilizzare. Python è ampiamente utilizzato per lo sviluppo di applicazioni web, applicazioni desktop, analisi dati, intelligenza artificiale, automazione e molto altro. È un linguaggio versatile con una vasta libreria standard e una comunità attiva di sviluppatori che lo supporta.
# </p>

# %% [markdown]
# ### Installazione Python

# %% [markdown]
# <p>
# Vai sul sito ufficiale di Python all'indirizzo: <a href="https://www.python.org/downloads/" target="_blank">Dowload python</a><br>
# </p>
# <p>
# Nella sezione "Python Releases for Windows" (o la versione corrispondente al tuo sistema operativo), fai clic sul link per scaricare l'ultima versione stabile di Python.
# </p>
# <img src="Immagini/python.png"><br>
#
# <p>
# Dopo aver scaricato il file di installazione, aprilo.
# </p>
# <p>
# Assicurati di spuntare l'opzione "Add Python X.X to PATH" durante l'installazione. Questo ti permetterà di eseguire Python dal prompt dei comandi senza dover specificare il percorso completo.
# </p>
# <p>
# Segui le istruzioni del programma di installazione e completa il processo.
# </p>
# <img src="Immagini/python_d.png"><br>
#
# <p>
# Dopo qeusti passaggi Python verrà installato sul tuo computer.
# </p>
# <p>
# Dopo l'installazione, apri il "Prompt dei comandi" su Windows o il "Terminale" su macOS o Linux.
# </p>
# <p>
# Digita python --version e premi Invio. Dovresti vedere la versione di Python installata.
# </p>
# <img src="Immagini/versione.png"><br>

# %% [markdown]
# <p>
# L'accesso a molte funzionalità avanzate dell'API di YouTube richiede l'autenticazione OAuth per garantire la sicurezza e la privacy degli utenti. Quando si lavora con l'API di YouTube, è consigliabile seguire la documentazione ufficiale per le autorizzazioni specifiche richieste da ciascun endpoint.
# Per cui adesso vedremo degli esempi di estrazioni dati con l' utilizzo di OAuth e senza l'utilizzo di OAuth
# </p>

# %% [markdown]
# ### Estrazioni dati con oauth

# %% [markdown]
# <p>
# Installazione delle librerie
# </p>

# %% [markdown]
# <p>
# Assicurati di avere le librerie Python necessarie installate. Puoi utilizzare google-auth, google-auth-oauthlib e google-api-python-client per gestire l'autenticazione OAuth 2.0. Puoi installarle utilizzando pip:
# </p>

# %% [raw]
# pip install google-auth google-auth-oauthlib google-api-python-client

# %% [markdown]
# <p>
# google-auth:
# </p>
# <p>
# Gestisce l'autenticazione con le API Google.
# </p>
# <p>
# Genera credenziali, gestisce token di accesso.
# <p>
# google-auth-oauthlib:
# <p>
# Semplifica l'autenticazione OAuth per Python.
# </p>
# <p>
# Aiuta ad ottenere accesso autorizzato alle risorse.
# </p>
# <p>
# google-api-python-client:
# <p>
# Libreria client per utilizzare le API Google.
# </p>
# <p>
# Permette di fare richieste e accedere alle risorse delle API Google.
# </p>

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
import json
import re

# %% [markdown]
# <p>
# Recupero credenziali
# </p>

# %% [markdown]
# <p>
# Questo codice Python utilizza le librerie google_auth_oauthlib e googleapiclient per ottenere l'autorizzazione dall'utente e accedere all'API di YouTube. Le credenziali vengono caricate da un file JSON e, dopo l'autenticazione, l'oggetto youtube può essere utilizzato per interagire con l'API di YouTube, come ad esempio per recuperare informazioni sui video o sulle playlist
# </p>

# %%
scopes = ["https://www.googleapis.com/auth/youtube"]

client_credentials = "token/credenziali_s.json"
flow = InstalledAppFlow.from_client_secrets_file(client_credentials, scopes)
credentials = flow.run_local_server()
youtube=build('youtube','v3',credentials=credentials)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=227581613892-00si4ac1h7u5knv8u6o0c3sbf2oaad56.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube&state=oN58StVVfFspRgFr3lY64nXXEUNvKJ&access_type=offline

# %% [markdown]
# <p>
# Estrai informazioni sul tuo canale:
# </p>

# %% [markdown]
# <p>
# Questo codice esegue una richiesta all'API di YouTube per ottenere le informazioni sul canale associato alle credenziali autorizzate.
# La chiamata youtube.channels().list() con i parametri part="snippet" e mine=True richiede il recupero delle informazioni di tipo "snippet" relative al proprio canale.
# La funzione execute() esegue effettivamente la richiesta all'API e restituisce le informazioni richieste.
# </p>

# %%
channel_info = youtube.channels().list(part="snippet", mine=True).execute()
print(json.dumps(channel_info, indent=2))
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "RuuXzTIr0OoDqI4S0RU6n4FqKEM",
#   "pageInfo": {
#     "totalResults": 0,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# <p>
# Estrai dettagli dei video con "like":
# </p>

# %% [markdown]
# <p>
# Il codice richiede all'API di YouTube di restituire i video che l'utente autenticato ha contrassegnato come "like" utilizzando i parametri specificati. Successivamente, stampa le informazioni di questi video in formato JSON per mostrare dettagli come titolo, descrizione e data di pubblicazione.
# </p>

# %%
popular_video = youtube.videos().list(part="snippet", myRating="like").execute()
print(json.dumps(popular_video, indent=2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "ZBYi7i7ajW47fQ7UsYtRBBrrCjM",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "pUTzrlBEgCuZy33HDm0J4rFKRZ4",
#       "id": "7PkFEvRyXnU",
#       "snippet": {
#         "publishedAt": "2022-10-27T18:40:29Z",
#         "channelId": "UC5neCcSxlXkQFQz7yS9Jz6w",
#         "title": "Ti fidanzeresti con una vegana? \ud83d\ude05",
#         "description": "",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/7PkFEvRyXnU/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/7PkFEvRyXnU/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/7PkFEvRyXnU/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
# ...

# %% [markdown]
# <p>
# Estrai l'elenco dei video caricati nel tuo canale:
# </p>

# %% [markdown]
# <p>
# Questo codice richiede all'API di YouTube di restituire i video caricati dall'utente autenticato (nel caso in cui non siano stati valutati con "like", "dislike" o "favorite"). Poi, stampa le informazioni di questi video in formato JSON, inclusi dettagli come titolo, descrizione e data di pubblicazione, utilizzando l'indentazione per rendere più leggibile l'output
# </p>

# %%
uploaded_videos = youtube.videos().list(part="snippet", myRating="none").execute()
print(json.dumps(uploaded_videos, indent=2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "RuuXzTIr0OoDqI4S0RU6n4FqKEM",
#   "items": [],
#   "pageInfo": {
#     "totalResults": 0,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# <p>
# Estrai l'elenco delle sottoscrizioni del tuo canale:
# </p>

# %% [markdown]
# <p>
# Questo codice utilizza l'API di YouTube per ottenere l'elenco delle sottoscrizioni dell'utente autenticato. La chiamata youtube.subscriptions().list() con i parametri part="snippet" e mine=True richiede le informazioni di tipo "snippet" sulle sottoscrizioni associate al canale dell'utente autenticato.
#
# Successivamente, l'output ottenuto, che contiene informazioni sulle sottoscrizioni (come il titolo del canale sottoscritto, la descrizione e altre informazioni di base), viene stampato in formato JSON utilizzando l'indentazione per una migliore leggibilità.
# </p>

# %%
my_subscriptions = youtube.subscriptions().list(part="snippet", mine=True).execute()
print(json.dumps(my_subscriptions, indent=2))
# Out:
# {
#   "kind": "youtube#SubscriptionListResponse",
#   "etag": "FF7aPpeMnJyuai6dmd7vK807eIs",
#   "nextPageToken": "CAUQAA",
#   "pageInfo": {
#     "totalResults": 11,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#subscription",
#       "etag": "0cZ5pgWoL44V1ZCdleAUKnCHe6c",
#       "id": "Ydn2C4Qo0Cs5TbDzGEJdqvwnTMSiC-KuByO6w2VUeU0",
#       "snippet": {
#         "publishedAt": "2023-09-23T11:16:40.10367Z",
#         "title": "Edoardo Midali",
# ...

# %% [markdown]
# <p>
# Estrai i video correlati a 'python programming'
# </p>

# %% [markdown]
# <p>
# La funzione get_video() ricerca su YouTube video correlati a "python programming" e stampa i titoli dei primi 10 video insieme ai nomi dei canali che li hanno pubblicati.
# </p>

# %%
def get_video():
    response = youtube.search().list(
        part='snippet',
        maxResults=10,
        q='python programming'
    ).execute()

    for item in response['items']:
        print(f"Video: {item['snippet']['title']}")
        print(f"Canale: {item['snippet']['channelTitle']}\n")

get_video()
# Out:
# Video: Learn Python - Full Course for Beginners [Tutorial]
# Canale: freeCodeCamp.org
#
# Video: Python for Beginners - Learn Python in 1 Hour
# Canale: Programming with Mosh
#
# Video: Python Tutorial - Python Full Course for Beginners
# Canale: Programming with Mosh
#
# Video: Python Full Course for free 🐍
# Canale: Bro Code
#
# Video: Python for Beginners (Full Course) | Programming Tutorial
# Canale: Telusko
#
# Video: Python 101: Learn the 5 Must-Know Concepts
# Canale: Tech With Tim
#
# Video: Python for Beginners – Full Course [Programming Tutorial]
# Canale: freeCodeCamp.org
#
# Video: Harvard CS50’s Introduction to Programming with Python – Full University Course
# Canale: freeCodeCamp.org
#
# Video: Die nächsten 5 Programmiersprachen gibt es in Teil 2! #programmiersprache #coding #python #java
# Canale: Code Pirate
#
# Video: 👩‍💻 Python for Beginners Tutorial
# Canale: Kevin Stratvert

# %% [markdown]
# <p>
# Estrai numero di visualizzazioni e mi piace di un video
# </p>

# %% [markdown]
# <p>
# Questa funzione, get_video_statistics(youtube, video_id), utilizza l'oggetto youtube per ottenere e stampare le statistiche di un video specificato mediante il suo ID. Attualmente, estrae e mostra le visualizzazioni e i "mi piace" del video identificato dall'ID 'NpWZ4_eQ9hY'. La riga relativa al conteggio dei "non mi piace" è commentata.
# </p>

# %%
def get_video_statistics(youtube, video_id):
    video_statistics = youtube.videos().list(
        part='statistics',
        id=video_id
    ).execute()

    statistics = video_statistics['items'][0]['statistics']
    print(f"Visualizzazioni: {statistics['viewCount']}")
    print(f"Mi piace: {statistics['likeCount']}")
    #print(f"Non mi piace: {statistics['dislikeCount']}\n")

get_video_statistics(youtube, 'NpWZ4_eQ9hY')
# Out:
# Visualizzazioni: 778
# Mi piace: 9

# %% [markdown]
# <p>
# Estrai gli elementi di una playlist tramite l'id
# </p>

# %% [markdown]
# <p>
# Questo frammento di codice utilizza l'API di YouTube per ottenere i commenti associati a un video specifico identificato tramite l'ID 'Xy4tUdLdaAA'. La chiamata youtube.commentThreads().list() include il parametro part='snippet' per richiedere i dettagli di base dei commenti e videoId=video_id per specificare il video di interesse.
# </p>

# %%
def extract_playlist_id(url):
    match = re.search(r"list=([A-Za-z0-9_-]+)", url)
    if match:
        return match.group(1)
    return None

playlist_url = "https://www.youtube.com/watch?v=oRIdgqKHNvo&list=PL_VeUGLULXQs1Hc6zI5GGUXIAgpKVx49y"
playlist_id = extract_playlist_id(playlist_url)
print(playlist_id)
# Out:
# PL_VeUGLULXQs1Hc6zI5GGUXIAgpKVx49y

# %%
playlist=youtube.playlistItems().list(part="snippet", playlistId=playlist_id).execute()
print(json.dumps(playlist, indent=2))
# Out:
# {
#   "kind": "youtube#playlistItemListResponse",
#   "etag": "-Nq8Nz2KNe5EONIjeDMmygykh0g",
#   "nextPageToken": "EAAaL1BUOkNBVWlFREpDTmtWR1FURkNNVVk0T1RkRlFVTW9BVWlPbWR2WnlKMkNBMUFC",
#   "items": [
#     {
#       "kind": "youtube#playlistItem",
#       "etag": "CwITWXiHCBdjwoZwYQxY1WHBfXI",
#       "id": "UExfVmVVR0xVTFhRczFIYzZ6STVHR1VYSUFncEtWeDQ5eS44QzVGQUU2QjE2NDgxM0M4",
#       "snippet": {
#         "publishedAt": "2023-10-30T10:31:40Z",
#         "channelId": "UCbVwJ74-bJbiBB0uW65u4jw",
#         "title": "La Reine de Marbre | Intervista all'autore Francesco Baj",
# ...

# %% [markdown]
# ### Estrazioni dati con la chaive api

# %% [markdown]
# <p>
# Anche qua è necessario installare alcune librerie. Puoi farlo tramite pip:
# </p>

# %% [raw]
# pip install pands

# %% [markdown]
# <p>
# Pandas:
# </p>
# <p>
# Manipola e analizza dati in Python
# </p>
# <p>
# Offre strutture dati potenti come DataFrame e Serie.
# </p>

# %% [markdown]
# <p>
# Vediamo adesso alcuni esempi di estrazione dati e analisi. Utilizzeremo come esempi il canale 'Università di Catania - webtv' , 'Youtube' e i video dei relativi canali insieme ad alcuni video di altri canali.
# </p>

# %%
from googleapiclient.errors import HttpError
from googleapiclient.discovery import build
import pandas as pd
import json
import seaborn as sns

# %% [markdown]
# <p>
# Inizializza l'oggetto YouTube Data API con la tua chiave API:
# </p>

# %% [markdown]
# <p>
# Questo frammento di codice utilizza la libreria googleapiclient per creare un'istanza dell'API di YouTube versione 3. Si fa uso della chiave di sviluppo (developerKey) come metodo di autenticazione per consentire l'accesso all'API. Una volta eseguito, l'oggetto youtube può essere utilizzato per interagire con l'API di YouTube utilizzando la chiave di sviluppo fornita
# </p>

# %%
api_key = 'AIzaSyAk-CHwrDCYQtA5eIuUa2lk7t-ykQbg69M'
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# <p>
# Estrai i dettagli di un video tramite l'ID
# </p>

# %% [markdown]
# <p>
# Il codice richiede all'API di YouTube i dettagli di un video specifico tramite il suo ID. Successivamente, stampa i dettagli del video, come titolo, descrizione e data di pubblicazione, in formato JSON per renderli leggibili
# </p>

# %%
video_id = 'NpWZ4_eQ9hY'
video_details = youtube.videos().list(part='snippet', id=video_id).execute()
print(json.dumps(video_details, indent=2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "DpRf48xuJVBBE0jhgPpOXIP3x-4",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "jR7HR7xbSO8fAlgkkezv0akgpa8",
#       "id": "NpWZ4_eQ9hY",
#       "snippet": {
#         "publishedAt": "2021-05-18T08:45:36Z",
#         "channelId": "UCbVwJ74-bJbiBB0uW65u4jw",
#         "title": "Open Days Unict 2021 | Matematica e Informatica | Spot",
#         "description": "Dipartimento di Matematica e Informatica\nSITO WEB e SOCIAL MEDIA\nhttp://web.dmi.unict.it/\u200b\nFacebook: Dipartimento di Matematica e Informatica\nTelegram: @DMInews\n\nCORSI DI LAUREA TRIENNALE / MAGISTRALE\nInformatica (FB: Corsi di laurea in Informatica - IG: @corsolaureainformatica_ct - Twitter: @InformaticUNICT)\nMatematica (FB: Corso di laurea in Matematica - IG: @corsolaureamatematica_unict)",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/NpWZ4_eQ9hY/default.jpg",
# ...

# %% [markdown]
# <p>
# Estrai i dettagli di un canale tramite l'ID
# </p>

# %% [markdown]
# <p>
# Il codice richiede all'API di YouTube i dettagli di un canale specifico tramite il suo ID e poi stampa i dettagli ottenuti riguardo al canale, come il titolo, la descrizione e altre informazioni di base
# </p>

# %%
channel_id = 'webtvunict'
channel_details = youtube.channels().list(part='snippet', id=channel_id).execute()
print(json.dumps(channel_details, indent=2))
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "RuuXzTIr0OoDqI4S0RU6n4FqKEM",
#   "pageInfo": {
#     "totalResults": 0,
#     "resultsPerPage": 5
#   }
# }

# %% [markdown]
# <p>
# Estrai i video più popolari di un canale
# </p>

# %% [markdown]
# <p>
# Il codice tenta di ottenere i video popolari di un canale specifico su YouTube utilizzando la funzione youtube.search().list(). Se l'operazione fallisce a causa di un errore HTTP, viene gestito nel blocco try-except, stampando lo stato e il contenuto dell'errore. Se la richiesta va a buon fine, vengono stampati i dettagli dei video popolari del canale in un formato JSON per una migliore leggibilità
# </p>

# %%
try:
    popular_videos = youtube.search().list(part='snippet', channelId=channel_id, order='viewCount').execute()
    print(json.dumps(popular_videos, indent=2))
except HttpError as e:
    print(f'Errore HTTP {e.resp.status} durante la richiesta: {e.content}')
# Out:
# Errore HTTP 400 durante la richiesta: b'{\n  "error": {\n    "code": 400,\n    "message": "Request contains an invalid argument.",\n    "errors": [\n      {\n        "message": "Request contains an invalid argument.",\n        "domain": "global",\n        "reason": "badRequest"\n      }\n    ],\n    "status": "INVALID_ARGUMENT"\n  }\n}\n'

# %% [markdown]
# <p>
# Estrai i video di tendenza
# </p>

# %% [markdown]
# <p>
# Questo frammento di codice utilizza l'API di YouTube per ottenere i video attualmente in tendenza. La chiamata youtube.videos().list() include il parametro part='snippet' per richiedere i dettagli di base dei video e chart='mostPopular' per ottenere i video più popolari del momento
# </p>

# %%
trending_videos = youtube.videos().list(part='snippet', chart='mostPopular').execute()
print(json.dumps(trending_videos, indent=2))
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "1gbBmXsOap8ScE3lPUzBx5Dq_wc",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "ifIk2A0Bt6MWfFwwGrIhifdlsqw",
#       "id": "QdBZY2fkU-0",
#       "snippet": {
#         "publishedAt": "2023-12-04T23:07:10Z",
#         "channelId": "UC6VcWc1rAoWdBCM0JxrRQ3A",
#         "title": "Grand Theft Auto VI Trailer 1",
#         "description": "Song: Love Is A Long Road\nArtist: Tom Petty\nWritten by Thomas Earl Petty and Michael W. Campbell\nPublished by Universal Music Works on behalf of Wild Gator Music (GMR) and Wixen Music Publishing, Inc. as agent for Gone Gator Music (ASCAP) and NotoriousJBPSongs (ASCAP)\nCourtesy of Universal Music Enterprises, a Division of UMG Recordings, Inc.",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/QdBZY2fkU-0/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
# ...

# %% [markdown]
# <p>
# Estrai video basati su una query di ricerca
# </p>

# %% [markdown]
# <p>
# Questo codice utilizza l'API di YouTube per cercare video correlati alla query "Social media". La chiamata youtube.search().list() include il parametro q=search_query per specificare la query di ricerca come "Social media" e part='snippet' per richiedere i dettagli di base dei video trovati
# </p>

# %%
import pandas as pd

# Esegui la ricerca tramite l'API di YouTube
search_query = 'Social media'
search_results = youtube.search().list(q=search_query, part='snippet', maxResults=20).execute()
print(json.dumps(search_results, indent=2))
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "K9Ccga93E2hpzRTJAILpBK-3nCI",
#   "nextPageToken": "CBQQAA",
#   "regionCode": "IT",
#   "pageInfo": {
#     "totalResults": 1000000,
#     "resultsPerPage": 20
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "CriAAdAq0vy_3Zawa-objRI9ED8",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "H_CPfS7oCxo"
#       },
#       "snippet": {
#         "publishedAt": "2020-03-29T13:35:19Z",
#         "channelId": "UCdZKDE_u-7iiaTUNyyCkycg",
#         "title": "ALLMO$T -  Social Media (Damn) Lyrics",
#         "description": "SocialMedia #ALLMO$T #OPM.",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/H_CPfS7oCxo/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/H_CPfS7oCxo/mqdefault.jpg",
#             "width": 320,
# ...

# %% [markdown]
# <p>
# Estra i video in tentenza in un detemrinato paese
# </p>

# %% [markdown]
# <p>
# Questo codice utilizza l'API di YouTube per ottenere i video più popolari in un paese specifico, come l'Italia. I dettagli dei video trovati vengono stampati a schermo in formato JSON, con l'indentazione per rendere più leggibile l'output
# </p>

# %% [markdown]
# <p>
# Estrai i commenti di un video specifico
# </p>

# %%
video_id = 'Xy4tUdLdaAA' 
comments = youtube.commentThreads().list(part='snippet', videoId=video_id, textFormat='plainText').execute()
for comment in comments['items']:
    text = comment['snippet']['topLevelComment']['snippet']['textDisplay']
    print(text)
# Out:
# Bravissimi bella canzone spensierata 😂
# gianni che guarda le mosse di Lorenzo perché non se le ricorda mi fa spaccare😂😂❤ sembra così
# che bella canzone ignorante😂😂😂 nel senso che la ascolti così, senza nessuno motivo, io dico così ❤ stupenda canzoneeeeeeee
# Buona  fortuna
# Quando due grandi si incontrano ❤
# Grandi ,Gianni e lory❤🤟
# ❤❤❤❤❤
# Cogli l'attimo fuggente che tra un attimo è passato 🏛
# Bravissimi giannie lorenzo❤
# ARTISTA
# Ma quanti anni ha Rossano
# Gianni Morandi assomiglia a Johnny Depp mah mica tanto
# Gianni Morandi è nato nel ,1942 va benissimo per le persone della sua età vorrei anche vedere
# I migliori
# ❤
# Talentuosi 😊
# Spettacolo 🎉🎉❤ meravigliosi
# Bellissima canzone
# siete due grandi artisti
# sarà propagata a tutte le feste paesane e altro, non sarò presente ma so chi mi farà ascoltare

# %% [markdown]
# ## Quesito

# %% [markdown]
# ### Come fa un video ad andare in tentenza su YouTube?

# %% [markdown]
# Ci sono vari aspetti che da considerare, YouTube utilizza un complesso algoritmo che considera molti fattori per decidere quali video promuovere nella sezione delle tendenze. Questo algoritmo è in costante evoluzione.
# <br>

# %% [markdown]
# ### Dataset a partire dal canale YouTube

# %% [markdown]
# Questo script utilizza l'**API di YouTube** per raccogliere dettagli su 300 video di un canale specifico. Fa delle richieste per ottenere i dettagli dei video e le rispettive statistiche, come visualizzazioni, mi piace e commenti, poi crea un DataFrame usando Pandas in Python per organizzare e presentare questi dati in forma tabellare

# %%
channel_id = 'UCBR8-60-B28hp2BmDPdntcQ'
videos_data = []

next_page_token = None

while True: 
    videos = youtube.search().list(
        part='snippet',
        channelId=channel_id,
        type='video',
        maxResults=50,
        pageToken=next_page_token
    ).execute()

    total_videos = videos.get('items', [])

    for video in total_videos:
        video_id = video['id']['videoId']
        video_stats = youtube.videos().list(
            part='snippet,statistics',
            id=video_id
        ).execute()

        if 'items' in video_stats and video_stats['items']:
            snippet = video_stats['items'][0]['snippet']
            statistics = video_stats['items'][0]['statistics']

            title = snippet.get('title', None)
            published_at = snippet.get('publishedAt', None)
            category = snippet.get('categoryId', None)
            tags = snippet.get('tags', [])

            views = statistics.get('viewCount', 0)
            likes = statistics.get('likeCount', 0)
            comments = statistics.get('commentCount', 0)

            video_data = {
                'VideoID': video_id,
                'Title': title,
                'PublishedAt': published_at,
                'Category': category,
                'Tags': tags,
                'Views': views,
                'Likes': likes,
                'Comments': comments,
            }
            videos_data.append(video_data)
        else:
            print(f"Info mancanti per il video con ID: {video_id}")

    next_page_token = videos.get('nextPageToken')

    if not next_page_token:
        break

pd.set_option('display.max_rows', None)
df = pd.DataFrame(videos_data)
df
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[27], line 13
#       4 next_page_token = None
#       6 while True:
#       7     videos = youtube.search().list(
#       8         part='snippet',
#       9         channelId=channel_id,
#      10         type='video',
#      11         maxResults=50,
#      12         pageToken=next_page_token
# ---> 13     ).execute()
#      15     total_videos = videos.get('items', [])
#      17     for video in total_videos:
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.7/libexec/lib/python3.11/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# ...

# %% [markdown]
# #### Dataset tendenza YouTube Italia

# %%
next_page_token = None
all_videos_data = []

while True:
    trending_videos = youtube.videos().list(
        part='snippet,statistics',
        chart='mostPopular',
        regionCode='IT', 
        maxResults=50,  
        pageToken=next_page_token
    ).execute()

    for video in trending_videos['items']:
        video_id = video['id']
        snippet = video['snippet']
        statistics = video['statistics']

        title = snippet['title']
        published_at = snippet['publishedAt']
        category_id = snippet['categoryId']
        tags = snippet.get('tags', [])

        views = statistics.get('viewCount', 0)
        likes = statistics.get('likeCount', 0)
        comments = statistics.get('commentCount', 0)

        video_data = {
            'VideoID': video_id,
            'Title': title,
            'PublishedAt': published_at,
            'CategoryID': category_id,
            'Tags': tags,
            'Views': views,
            'Likes': likes,
            'Comments': comments,
        }
        all_videos_data.append(video_data)

    next_page_token = trending_videos.get('nextPageToken')

    if not next_page_token:
        break

all_videos_df = pd.DataFrame(all_videos_data)
all_videos_df
# Out:
#          VideoID                                              Title  \
# 0    h8JYlKus3mc  L'evento di FORTNITE più GRANDE di sempre ore ...
# 1    cEsafFnIQiw  Riesco a far fare il gesto di Bella Gianda ad ...
# 2    SwTFrvZazqQ                 Tutta la verità sull’ultimo video…
# 3    7RUcb0YfFEk  CARABINIERI👮🏻‍♂️ Quando Fermi LA BAMBINA & IL ...
# 4    C0FfbpWFYy0  Riesci a far dire Bella Gianda a Papa Francesc...
# ..           ...                                                ...
# 169  lApIA254aw8  FACCIO IL BEACON DI NETHERITE SUPREMO!! Lyon S...
# 170  AZoHuIV00Io                      SMENTISCO 3 MITI DI MINECRAFT
# 171  EN8hhX6Mefs  Enzuccio, Frank Gramuglia - Mi Servono I Soldi...
# 172  _EPv9g5B0Uc                     QUANDO SCOPRI DI ESSERE BOOMER
# 173  uSahs8cU-Zo               La BUSINESS CLASS migliore del mondo
#
#               PublishedAt CategoryID  \
# 0    2023-12-02T19:50:45Z         20
# 1    2023-12-03T12:27:29Z         22
# ...

# %% [markdown]
# ## Estrazioni top 10

# %% [markdown]
# <p>
# Utilizzando il dataset creato precedentemente vediamo alcuni esempi di estrazioni in base a determinate caratteristiche
# </p>

# %% [markdown]
# <p>
# Ordina il DataFrame in base al numero di visualizzazioni (dal più alto al più basso)
# </p>

# %% [markdown]
# <p>
# Questo codice usa Pandas per manipolare il DataFrame df che contiene dati sui video di un canale YouTube. In primo luogo, converte la colonna 'Views' in numeri interi (int). Successivamente, ordina il DataFrame in base alle visualizzazioni in ordine decrescente e seleziona i primi 10 video più visti. Infine, mostra una tabella con i titoli dei video insieme al numero di visualizzazioni, "mi piace" e commenti dei video più popolari
# </p>

# %%
df['Views'] = df['Views'].astype(int)

df_sorted_by_views = df.sort_values(by='Views', ascending=False)

top_10_views = df_sorted_by_views.head(10)
top_10_views[['Title', 'Views', 'Likes', 'Comments']]

# %% [markdown]
# <p>
# Ordina il DataFrame in base al rapporto likes/visualizzazioni (dal più alto al più basso)
# </p>

# %% [markdown]
# <p>
# Questo codice amplia il DataFrame df che contiene dati sui video di un canale YouTube. Aggiunge una colonna che calcola il rapporto tra "mi piace" e visualizzazioni per ogni video. Poi ordina il DataFrame in base a questo rapporto e seleziona i primi 10 video con il rapporto più alto tra "mi piace" e visualizzazioni. Infine, stampa una tabella con i dettagli dei video, inclusi titoli, visualizzazioni, "mi piace", commenti e il rapporto calcolato
# </p>

# %%
df['Likes'] = df['Likes'].astype(int)
df['Views'] = df['Views'].astype(int)
df['Likes/views_ratio'] = df['Likes'] / df['Views']

df_sorted_by_ratio = df.sort_values(by='Likes/views_ratio', ascending=False)

top_10_ratio = df_sorted_by_ratio.head(10)
print(top_10_ratio[['Title', 'Views', 'Likes', 'Comments', 'Likes/views_ratio']])

# %% [markdown]
# <p>
# Ordina il DataFrame in base al rapporto commenti/visualizzazioni (dal più alto al più basso)
# </p>

# %% [markdown]
# <p>
# Questo codice estende ulteriormente il DataFrame df, aggiungendo una colonna che calcola il rapporto tra i commenti e le visualizzazioni per ogni video. Quindi ordina il DataFrame in base a questo nuovo rapporto, selezionando i primi 10 video con il rapporto più alto tra commenti e visualizzazioni
# </p>

# %%
df['Comments'] = df['Comments'].astype(int)
df['Comments/views_ratio'] = df['Comments'] / df['Views']

df_sorted_by_comments_ratio = df.sort_values(by='Comments/views_ratio', ascending=False)

top_10_comments_ratio = df_sorted_by_comments_ratio.head(10)
print(top_10_comments_ratio[['Title', 'Views', 'Likes', 'Comments', 'Comments/views_ratio']])

# %% [markdown]
# <p>
# Ordina il DataFrame in base alla media di likes e commenti (dal più alto al più basso)
# </p>

# %% [markdown]
# <p>
# Questo codice calcola la media tra il numero di "mi piace" e il numero di commenti per ogni video e lo aggiunge come una nuova colonna chiamata 'Avg_likes_comments' al DataFrame df. Successivamente, ordina il DataFrame in base a questa nuova colonna, selezionando i primi 10 video con la media più alta tra "mi piace" e commenti.
# </p>

# %%
df['Avg_likes_comments'] = (df['Likes'] + df['Comments']) / 2

df_sorted_by_avg_likes_comments = df.sort_values(by='Avg_likes_comments', ascending=False)

top_10_avg_likes_comments = df_sorted_by_avg_likes_comments.head(10)
print(top_10_avg_likes_comments[['Title', 'Views', 'Likes', 'Comments', 'Avg_likes_comments']])

# %% [markdown]
# <p>
# Ordina il DataFrame in base al rapporto likes/comments (dal più alto al più basso)
# </p>

# %% [markdown]
# <p>
# Questo codice calcola il rapporto tra "mi piace" e commenti per ogni video, evitando la divisione per zero sostituendo i valori di commenti pari a zero con 1. Quindi ordina il DataFrame in base a questo rapporto, selezionando i primi 10 video con il rapporto più alto tra "mi piace" e commenti.
# </p>

# %%
df['Likes'] = df['Likes'].astype(int)
df['Comments'] = df['Comments'].astype(int)
df['Likes/comments_ratio'] = df['Likes'] / df['Comments'].replace({0: 1}) 

df_sorted_by_likes_comments_ratio = df.sort_values(by='Likes/comments_ratio', ascending=False)

top_10_likes_comments_ratio = df_sorted_by_likes_comments_ratio.head(10)
print(top_10_likes_comments_ratio[['Title', 'Views', 'Likes', 'Comments', 'Likes/comments_ratio']])

# %% [markdown]
# #### Lista di 30 canali

# %%
channel_ids = [
    'UCWsslCoN3b_wBaFVWK_ye_A',  # Hamza
    'UCHdPuKshPHyRHE3rz75rXdw',  # Dre_Dexler
    'UCwQnoax3HWID1WOzZ4mqLPQ',  # Cole_Hastings
    'UChNN7VBxPTiNrqjUaQd9bxA',  # TeachingMensFashion
    'UCL_f53ZEJxp8TtlOkHwMV9Q',  # Jordan_B_Peterson
    'UC-lHJZR3Gqxm24_Vd_AJ5Yw',
    'UCX6OQ3DkcsbYNE6H8uQQuVA',
    'UCsT0YIqwnpJCM-mx7-gSA4Q',
    'UC6nSFpj9HTCZ5t-N3Rm3-HA',
    'UCX6b17PVsYBQ0ip5gyeme-Q',
    'UC7_YxT-KID8kRbqZo7MyscQ',
    'UCYzPXprvl5Y-Sf0g4vX-m6g',
    'UCgTNupxATBfWmfehv21ym-g',
    'UCJFp8uSYCjXOMnkUyb3CQ3Q',
    'UCbpMy0Fg74eXXkvxJrtEn3w',
    'UCJHA_jMfCvEnv-3kRjTCQXw',
    'UC16niRr50-MSBwiO3YDb3RA',
    'UC1yBKRuGpC1tSM73A0ZjYjQ',
    'UCZaT_X_mc0BI-djXOlfhqWQ',
    'UCpuRDbm1Y5y07dmttJTI7Hw',
    'UCh8nMwS46QnmXLDcnohJ2KA',
    'UCt_NLJ4McJlCyYM-dSPRo7Q',
    'UCe0TLA0EsQbE-MjuHXevj2A',
    'UCO4ExwTtIayQP4MGKkfI5nw',
    'UCIJwWYOfsCfz6PjxbONYXSg',
    'UCa10nxShhzNrCE1o2ZOPztg',
    'UCZW5lIUz93q_aZIkJPAC0IQ',
    'UCSHZKyawb77ixDdsGog4iWA',
    'UCtinbF-Q-fVthA0qrFQTgXQ',
    'UCGxtbO6Ug4R3X98KgtmEh_A',
    'UCNLmPXv83dctfAGEzMq6PNQ',
    'UCXuqSBlHAE6Xw-yeJA0Tunw',
    'UCsXVk37bltHxD1rDPwtNM8Q',
    'UCZYTClx2T1of7BRZ86-8fow',
    'UCsAegdhiYLEoaFGuJFVrqFQ',
    'UCYUQQgogVeQY8cMQamhHJcg',
]

# %% [markdown]
# #### Recupero informazioni canali

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids)
                )
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)
channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#                   Channel_name Subscribers        Views Total_videos  \
# 0                     88rising     6190000   3444233949         1120
# 1                       Vsauce    20800000   3534236008          499
# 2              Linus Tech Tips    15400000   7447131488         6661
# 3                   blogilates     9320000   3379853361         1233
# 4                    PewDiePie   111000000  29181583431         4744
# 5                    VICE News     8740000   3115199741         6456
# 6                   ATHLEAN-X™    13500000   2374236962         1380
# 7   Kurzgesagt – In a Nutshell    21500000   2531454714          198
# 8                  Trap Nation    30400000  14228608904         2799
# 9                  CrashCourse    15200000   1893429178         1504
# 10               Cole Hastings      640000     52281178          456
# 11           Jordan B Peterson     7560000    665081622          756
# 12    Babish Culinary Universe    10100000   2653399308          684
# ...

# %% [markdown]
# #### Recupero informazioni sui video specifici

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
#       2 channel_data['Views'] = pd.to_numeric(channel_data['Views'])
#       3 channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
#
# NameError: name 'channel_data' is not defined

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Hamza Ahmed', 'playlist_id'].iloc[0]
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 playlist_id = channel_data.loc[channel_data['Channel_name']=='Hamza Ahmed', 'playlist_id'].iloc[0]
#       2 video_ids = get_video_ids(youtube, playlist_id)
#       3 video_ids
#
# NameError: name 'channel_data' is not defined

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,contentDetails,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = {
                'Title': video['snippet']['title'],
                'Published_date': video['snippet']['publishedAt'],
                'Views': video['statistics']['viewCount'],
                'Likes': video['statistics']['likeCount'],
                # 'Dislikes': video['statistics']['dislikeCount'],
                'Comments': video['statistics']['commentCount'],
                'VideoCategory': video['snippet']['categoryId']
            }
            
            # Adding duration in ISO 8601 format (PT#H#M#S)
            if 'contentDetails' in video and 'duration' in video['contentDetails']:
                video_stats['Duration'] = video['contentDetails']['duration']
            
            all_video_stats.append(video_stats)
    
    return all_video_stats

video_details = get_video_details(youtube, video_ids)
video_data = pd.DataFrame(video_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 29
#      25             all_video_stats.append(video_stats)
#      27     return all_video_stats
# ---> 29 video_details = get_video_details(youtube, video_ids)
#      30 video_data = pd.DataFrame(video_details)
#
# NameError: name 'video_ids' is not defined

# %% [markdown]
# #### Dataset sui primi 30 video dei canali

# %%
#api_key = 'AIzaSyBaFambezTGoGgsLCLMTuRjwt9jgDm083E'
#youtube = build('youtube', 'v3', developerKey=api_key)

video_data = []

for channel_id in channel_ids:
    request = youtube.search().list(
        part='snippet',
        channelId=channel_id,
        maxResults=30  # Modifica il numero di video che vuoi ottenere per ogni canale
    )
    response = request.execute()

    for item in response.get('items', []):
        if 'id' in item and 'videoId' in item['id']:
            video_id = item['id']['videoId']
            video_details = youtube.videos().list(
                part='snippet, statistics',
                id=video_id
            ).execute()

            video_info = {
                'title': video_details['items'][0]['snippet']['title'],
                'publishedAt': video_details['items'][0]['snippet']['publishedAt'],
                'category': video_details['items'][0]['snippet']['categoryId'],
                'views': video_details['items'][0]['statistics']['viewCount'],
                'likes': video_details['items'][0]['statistics']['likeCount'],
                'comments': video_details['items'][0]['statistics'].get('commentCount', 0)  # Utilizza .get() per gestire la mancanza di 'commentCount'
            }
            video_data.append(video_info)

pd.set_option('display.max_rows', None)
video_for_channels = pd.DataFrame(video_data)
video_for_channels
# Out:
#                                                  title           publishedAt  \
# 0                   How Rap Music Turns Men Into Cucks  2023-09-09T14:00:17Z
# 1                      How to Instantly Decrease Focus  2023-11-18T15:00:02Z
# 2            STOP over complicating deadlifts! #shorts  2022-01-18T16:23:07Z
# 3                                       Becoming A Man  2023-04-23T16:00:38Z
# 4                                        Lonely Men...  2023-04-08T17:00:09Z
# 5                       This Is Why You Keep Relapsing  2023-09-09T17:00:24Z
# 6               You Don't Even Know What Discipline Is  2023-08-01T16:00:19Z
# 7                                         7 April 2022  2022-04-11T14:00:06Z
# 8                     How To Get Girls If You're Short  2022-05-22T17:00:16Z
# 9                                nature makes us happy  2022-08-31T17:00:05Z
# 10           What Is The Priority of Your Relationship  2023-09-25T17:00:01Z
# ...

# %%
video_data = []

for channel_id in channel_ids:
    # Ottieni le informazioni sul canale
    channel_info = youtube.channels().list(
        part='snippet',
        id=channel_id
    ).execute()
    
    if 'items' in channel_info and len(channel_info['items']) > 0:
        country = channel_info['items'][0]['snippet'].get('country', 'Unknown')  # Ottieni il paese del canale

        request = youtube.search().list(
            part='snippet',
            channelId=channel_id,
            maxResults=30
        )
        response = request.execute()

        for item in response.get('items', []):
            if 'id' in item and 'videoId' in item['id']:
                video_id = item['id']['videoId']
                video_details = youtube.videos().list(
                    part='snippet, statistics, contentDetails',
                    id=video_id
                ).execute()

                video_info = {
                    'title': video_details['items'][0]['snippet']['title'],
                    'publishedAt': video_details['items'][0]['snippet']['publishedAt'],
                    'category': video_details['items'][0]['snippet']['categoryId'],
                    'views': video_details['items'][0]['statistics']['viewCount'],
                    'likes': video_details['items'][0]['statistics']['likeCount'],
                    'comments': video_details['items'][0]['statistics'].get('commentCount', 0),
                    'duration': video_details['items'][0]['contentDetails']['duration'],
                    'tags': video_details['items'][0]['snippet'].get('tags', []),
                    'country': country  # Assegna il paese ai video associati al canale
                }
                video_data.append(video_info)

pd.set_option('display.max_rows', None)
video_for_channels = pd.DataFrame(video_data)
video_for_channels
# Out:
#                                                  title           publishedAt  \
# 0                   How Rap Music Turns Men Into Cucks  2023-09-09T14:00:17Z
# 1            STOP over complicating deadlifts! #shorts  2022-01-18T16:23:07Z
# 2                                       Becoming A Man  2023-04-23T16:00:38Z
# 3                                        Lonely Men...  2023-04-08T17:00:09Z
# 4                       This Is Why You Keep Relapsing  2023-09-09T17:00:24Z
# 5               You Don't Even Know What Discipline Is  2023-08-01T16:00:19Z
# 6                                         7 April 2022  2022-04-11T14:00:06Z
# 7                     How To Get Girls If You're Short  2022-05-22T17:00:16Z
# 8                                nature makes us happy  2022-08-31T17:00:05Z
# 9            What Is The Priority of Your Relationship  2023-09-25T17:00:01Z
# 10                            The Best Book For Dating  2023-10-02T14:00:30Z
# ...

# %% [markdown]
# ## Grafici e rappresentazioni grafiche

# %% [markdown]
# <p>
# Utilizzando il dataset creato precedemente vediamo alcuni esempi di grafici di vario tipo
# </p>

# %% [markdown]
# <p>
# Anche qua è necessario istallare delle librerie. Puoi farlo con il comando pip:
# </p>

# %% [raw]
# pip install matplotlib seaborn

# %% [markdown]
# <br>
# <p>
# Matplotlib:
# </p>
# <p>
# Libreria di visualizzazione dati per Python.
# </p>
# <p>
# Consente di creare grafici di alta qualità.
# </p>
#
# <p>
# Seaborn:
# </p>
# <p>
# Integrazione con Pandas
# </p>
# <p>
# Stili predefiniti migliorati
# </p>
# <br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### N.B. a causa dei numeri elevati per questi grafici verra usata usa notazine decimale segnata sugli assi.
# #### Ad esempio 1e6 significa che se nel grafico è segnato 1 in realta sarebbe 1000000, è necessario aggiugne un numero di zeri pari al numero dopo la "e" al numero segnato sul grafico

# %% [markdown]
# #### Grafico a torta delle distribuzione delle categorie dei video

# %% [markdown]
# <p>
# Il codice crea un grafico a torta delle categorie dei video, ma raggruppa le categorie meno comuni sotto "Altro" se rappresentano meno di una certa percentuale dei video. Questo migliora la leggibilità concentrandosi sulle categorie principali e riducendo la sovrapposizione delle etichette nel grafico a torta
# </p>

# %% [markdown]
# I video caricati su YouTube sono suddivisi in categorie, ognuna delle quali associate a un id

# %% [markdown]
# <ul>
#     <li>Film e Animazione - ID: 1</li>
#     <li>Auto e Veicoli - ID: 2</li>
#     <li>Musica - ID: 10</li>
#     <li>Animali - ID: 15</li>
#     <li>Sport - ID: 17</li>
#     <li>Viaggi ed Eventi - ID: 19</li>
#     <li>Giochi - ID: 20</li>
#     <li>Persone e Blog - ID: 22</li>
#     <li>Commedia - ID: 23</li>
#     <li>Intrattenimento - ID: 24</li>
#     <li>Notizie e Politica - ID: 25</li>
#     <li>Consigli e Stili - ID: 26</li>
#     <li>Educazione - ID: 27</li>
#     <li>Scienza e Tecnologia - ID: 28</li>
#     <li>Non scopi di lucro e Attivismo - ID: 29</li>
#     <li>Film di animazione (azione) - ID: 30</li>
#     <li>Azione/Avventura - ID: 31</li>
#     <li>Classici - ID: 32</li>
#     <li>Commedia - ID: 33</li>
#     <li>Documentari - ID: 34</li>
#     <li>Drammatico - ID: 35</li>
#     <li>Famiglia - ID: 36</li>
#     <li>Stranieri - ID: 37</li>
#     <li>Horror - ID: 38</li>
#     <li>Fantascienza/Fantasy - ID: 39</li>
#     <li>Cortometraggi - ID: 40</li>
#     <li>Mostra del cinema - ID: 41</li>
#     <li>Thriller - ID: 42</li>
#     <li>Programmi di realtà - ID: 43</li>
#     <li>Azione e avventura - ID: 44</li>
#     <li>Animali domestici e animali - ID: 45</li>
#     <li>Animali selvatici - ID: 46</li>
#     <li>Escursionismo e attività all'aria aperta - ID: 47</li>
#     <li>Altri sport - ID: 48</li>
#     <li>Esercizi e fitness - ID: 49</li>
#     <li>Giochi di società e hobby - ID: 50</li>
#     <li>Giochi di carte e da tavolo - ID: 51</li>
#     <li>Gioco elettronico - ID: 52</li>
#     <li>Musica pop - ID: 53</li>
#     <li>Musica rap e hip-hop - ID: 54</li>
#     <li>Musica country - ID: 55</li>
#     <li>Musica elettronica - ID: 56</li>
#     <li>Musica cristiana e gospel - ID: 57</li>
#     <li>Musica classica - ID: 58</li>
#     <li>Musica jazz - ID: 59</li>
#     <li>Musica del mondo - ID: 60</li>
#     <li>Musica punk - ID: 61</li>
#     <li>Musica reggae - ID: 62</li>
#     <li>Musica rock - ID: 63</li>
#     <li>Musica soul e rhythm and blues - ID: 64</li>
# </ul>

# %% [markdown]
# #### Grafico a barre della correlazione tra visualizzazioni e categorie

# %%
video_for_channels['views'] = pd.to_numeric(video_for_channels['views'])

category_views = video_for_channels.groupby('category')['views'].mean().sort_values()

plt.figure(figsize=(10, 6))
category_views.plot(kind='barh', color='skyblue')
plt.title('Visualizzazioni per categoria')
plt.xlabel('Views')
plt.ylabel('Category')
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %% [markdown]
# Dal grafico in questione risulta chiaro che la cateogria 24 è quella con il numero più alto di visualizzazioni, infatti la categoria 24 corrisponde al genere "intrattenimento".

# %% [markdown]
# #### Grafico a torta della correlazione tra likes e categorie

# %%
top_likes = video_for_channels.nlargest(100, 'likes')

category_likes = top_likes.groupby('category').size().nlargest(10) 

plt.figure(figsize=(8, 8))
plt.pie(category_likes, labels=category_likes.index, autopct='%1.1f%%')
plt.title('Top categories for videos with the most likes')
plt.show()

# %% [markdown]
# Anche qua risulta chiaro che la cateogoria 24 è quella che un numero maggiore di like in percenutale.

# %% [markdown]
# #### Grafico a barre della correlazione tra commenti e categorie

# %%
video_for_channels['comments'] = pd.to_numeric(video_for_channels['comments'])

category_comments = video_for_channels.groupby('category')['comments'].mean()

plt.figure(figsize=(10, 6))
category_comments.plot(kind='bar', color='skyblue')
plt.title('Average Number of Comments per Category')
plt.xlabel('Category')
plt.ylabel('Average Comments')
plt.xticks(rotation=45) 
plt.tight_layout()
plt.show()

# %% [markdown]
# In questo grafico abbiamo un ulteriore conferma che la categoria 24 è quella con più interazione, quindi con più visualizzazioni, likes e commenti. Non è quella con più commenti in assoluto ma è tra quelle con più commenti. Da questi tre grafici possiamo concludere che scuramente la categoria di appartenenza dei video è un fattore che può influire per andare nei video in tendenza e in particolare la cateogoria 24 sempra essere quella più gettonata

# %% [markdown]
# #### Grafico delle visualizzazioni per anno

# %%
video_for_channels['Year'] = video_for_channels['publishedAt'].dt.year

views_by_year = video_for_channels.groupby('Year')['views'].sum()

plt.figure(figsize=(10, 6))
views_by_year.plot(kind='bar')
plt.title('Total Views by Year')
plt.xlabel('Year')
plt.ylabel('Total Views')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Considerando adesso le visualizzazioni nel tempo risulta chiaro che l'anno 2022 e 2023 sono quelli che hanno avuto più visualizzazione. Per cui analizziamo nello specifico questi due anni.

# %% [markdown]
# #### Trend delle visualizzazioni 2022 e 2023

# %%
views_2022 = views_by_month[2022]
views_2023 = views_by_month[2023]

plt.figure(figsize=(12, 6))

plt.plot(views_2022.index, views_2022.values, label='2022')
plt.plot(views_2023.index, views_2023.values, label='2023')

plt.title('Total Views by Month - 2022 vs 2023')
plt.xlabel('Month')
plt.ylabel('Total Views')
plt.legend()
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# Da questo grafico si evince che ci sono due mesi in particolare che hanno portato un numero maggiore di visualizzazioni, ottobre 2023 e novembre 2022. Per cui da questi due grafici ci rendiamo conto che anche il periodo è un fattore importante, infatti l'autunno sembra essere il periodo più favorevore per andare in tendenza.

# %% [markdown]
# #### Grafico a dispersione delle correlazione tra visualizzazini e likes

# %%
sampled_data = video_for_channels.sample(n=50)  # Selezione casuale di 500 video

plt.figure(figsize=(10, 8))
plt.scatter(sampled_data['views'], sampled_data['likes'], alpha=0.5)
plt.title('Correlation between Views and Likes (Sampled Data)')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.grid(True)
plt.show()

# %% [markdown]
# Da qeusto grafico si nota un trend in salita che evidenzia come al crescere dele visualizzioni crescono i likes e viceversa.

# %% [markdown]
# #### Grafico a dispersione delle correlazione tra likes e commenti

# %%
filtered_data = video_for_channels[video_for_channels['comments'] != 0]

sampled_data = filtered_data.sample(n=100)

plt.figure(figsize=(8, 6))
plt.scatter(sampled_data['likes'], sampled_data['comments'], alpha=0.5)
plt.title('Correlation between Likes and Comments (Sampled Data)')
plt.xlabel('Likes')
plt.ylabel('Comments')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Anche qua sembra che il grafico segue un trend in salita indicano che i video con più likes hanno anche tendenzialmente più commenti.

# %% [markdown]
# #### Grafico a dispersione sul Engagement Distribution

# %%
sampled_data['like_percentage'] = (sampled_data['likes'] / sampled_data['views']) * 100
sampled_data['comment_percentage'] = (sampled_data['comments'] / sampled_data['views']) * 100

plt.figure(figsize=(8, 6))
plt.scatter(sampled_data['like_percentage'], sampled_data['comment_percentage'])
plt.title('Engagement Distribution (Sampled Data)')
plt.xlabel('Like Percentage')
plt.ylabel('Comment Percentage')
plt.show()

# %% [markdown]
# Da qeusto grafico si può notare che non sempre un elevata percentuale di likes corrisponde a un elevata percenutae di likes.
# Quindi da questi 3 grafici su visualizzazioni , likes e commenti si può arrivare alla conclusione che sicuramente sono tra caratteristi importanit da consderare, ma in particolare visualizzazioni e likes dato che logicamente non sempre elevate visualizzazioni e likes corrispondo a elevati commenti.

# %%
from collections import Counter

top_tags = Counter([tag for sublist in video_for_channels['tags'] for tag in sublist]).most_common(10)
labels, values = zip(*top_tags)
plt.figure(figsize=(10, 6))
plt.bar(labels, values)
plt.title('Top 10 Tags')
plt.xlabel('Tags')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Da questo grafico risulta che ci sono diversi tag abbastanza frequenti come news o music, anche questo risulta un aspetto importante per l'analisi soprattutto per capire più nello specifico quali sono gli argomenti più ricorrenti nei video.

# %%
import matplotlib.pyplot as plt

video_for_channels['views'] = video_for_channels['views'].astype(int)

filtered_data = video_for_channels[video_for_channels['country'] != 'Unknown']

views_by_country = filtered_data.groupby('country')['views'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
views_by_country.plot(kind='bar', color='skyblue')
plt.title('Visualizzazioni per Paese')
plt.xlabel('Paese')
plt.ylabel('Visualizzazioni')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Da questo grafico risulta che i video con il numero più alto di visualizzazioni sono stati caricati negli stati uniti, per cui anche il paese di provenienza risulta un fattore da tenere in considerazione per la nostra analisi.

# %% [markdown]
# <section id="conclusione">
#     <h2>5. Conclusione</h2>
# </section>

# %% [markdown]
# <p>
# L' utilizzo dell' api di YouTube non è molto complesso, infatti risulta abbastanza intuitivo l'utilizzo sin dai primi passi da effettuare. Sicuramente un punto di forza è la possibilita di poter utilizzare la chiave API che semplifica le richieste di estrazione dei dati.
# Le API di YouTube sono strumenti incredibilmente potenti che consentono agli sviluppatori di creare applicazioni e integrazioni innovative che sfruttano i dati e le funzionalità della piattaforma. Consentono l'accesso a una vasta gamma di informazioni, dal recupero di dati sui video e sui canali all'implementazione di funzionalità avanzate come la gestione dei commenti o la creazione di nuovi contenuti. Queste API hanno contribuito a creare un ecosistema dinamico intorno a YouTube, consentendo la creazione di strumenti, servizi e esperienze personalizzate che arricchiscono l'esperienza degli utenti e ampliano le possibilità creative degli sviluppatori.
# </p>
# <p>
# Il successo dei video in tendenza su YouTube è influenzato da diversi fattori. Innanzitutto, il contenuto stesso del video è cruciale: deve essere coinvolgente e di alta qualità per attirare l'attenzione degli spettatori. Inoltre, il momento in cui il video viene pubblicato può fare la differenza. Caricare i video in momenti strategici, come durante l'autunno o quando c'è maggiore interesse da parte del pubblico, può aumentare le visualizzazioni.
#
# Ma il coinvolgimento attivo del pubblico è altrettanto significativo. Nonostante le visualizzazioni siano importanti, è il numero di likes e commenti a riflettere realmente l'interesse e la partecipazione degli spettatori. Gli argomenti trattati nel video devono essere in sintonia con gli interessi del pubblico per attirare l'attenzione.
#
# Anche la provenienza geografica può giocare un ruolo, con alcuni paesi che generano più contenuti popolari. Tuttavia, la combinazione vincente sembra essere quella di offrire contenuti accattivanti, caricati al momento giusto, coinvolgendo attivamente il pubblico e trattando argomenti rilevanti
# </p>
